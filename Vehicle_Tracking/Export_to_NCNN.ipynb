# %%
# !pip install -q ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.7 MB/s eta 0:00:00

# %%
# Download vehicle_best.pt and vehcle_custom_best.pt
# !gdown 17duAgT1PqRPoPemJnn0MdBNMDhrZIoZV
# !gdown 1FMUI9jOPzABelcjIfBqCndvcnVX0Yp4l
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=17duAgT1PqRPoPemJnn0MdBNMDhrZIoZV
# To: /content/vehicle_best.pt
# 100% 5.44M/5.44M [00:00<00:00, 51.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1FMUI9jOPzABelcjIfBqCndvcnVX0Yp4l
# To: /content/vehicle_custom_best.pt
# 100% 5.44M/5.44M [00:00<00:00, 60.0MB/s]

# %%
# Export to NCNN
from ultralytics import YOLO

pt_path = "/content/vehicle_best.pt"
model = YOLO(pt_path)
model.export(
    format="ncnn",
    half=True,
    optimize=False
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.4.63 🚀 Python-3.12.13 torch-2.11.0+cu128 CPU (Intel Xeon CPU @ 2.00GHz)
# WARNING ⚠️ NCNN export does not support end2end models, disabling end2end branch.
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO11n summary (fused): 101 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from '/content/vehicle_best.pt' with input shape (1, 3, 480, 480) BCHW and output shape(s) (1, 9, 4725) (5.2 MB)
# requirements: Ultralytics requirement ['ncnn'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# ...

# %%
# !zip -r -q /content/vehicle_best_ncnn_model.zip /content/vehicle_best_ncnn_model
from google.colab import files
files.download('/content/vehicle_best_ncnn_model.zip')

# %%
# Export to NCNN
from ultralytics import YOLO

pt_path = "/content/vehicle_custom_best.pt"
model = YOLO(pt_path)
model.export(
    format="ncnn",
    half=True,
    optimize=False
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.4.67 🚀 Python-3.12.13 torch-2.11.0+cu128 CPU (Intel Xeon CPU @ 2.00GHz)
# WARNING ⚠️ NCNN export does not support end2end models, disabling end2end branch.
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO11n summary (fused): 101 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from '/content/vehicle_custom_best.pt' with input shape (1, 3, 480, 480) BCHW and output shape(s) (1, 9, 4725) (5.2 MB)
# requirements: Ultralytics requirement ['ncnn'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# ...

# %%
# !zip -r -q /content/vehicle_custom_best_ncnn_model.zip /content/vehicle_custom_best_ncnn_model
from google.colab import files
files.download('/content/vehicle_custom_best_ncnn_model.zip')
