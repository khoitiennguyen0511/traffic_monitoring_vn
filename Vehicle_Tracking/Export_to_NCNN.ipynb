# %%
# !pip install -q ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 27.1 MB/s eta 0:00:00

# %%
# # Download vehicle_best.pt and vehcle_custom_best.pt
# !gdown 17duAgT1PqRPoPemJnn0MdBNMDhrZIoZV
# !gdown 1FMUI9jOPzABelcjIfBqCndvcnVX0Yp4l
# Download vehicle_best_320.pt and vehcle_custom_best_320.pt
# !gdown 1et-KLjMgPX3UP1Z8ve0NnbqmSqywExxN
# !gdown 119pOaSTZxgjsXBsp-O9Oa5o17PdrijpB
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1et-KLjMgPX3UP1Z8ve0NnbqmSqywExxN
# To: /content/vehicle_best_320.pt
# 100% 5.43M/5.43M [00:00<00:00, 31.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=119pOaSTZxgjsXBsp-O9Oa5o17PdrijpB
# To: /content/vehicle_custom_best_320.pt
# 100% 5.42M/5.42M [00:00<00:00, 29.0MB/s]

# %%
# Export to NCNN
from ultralytics import YOLO

pt_path = "/content/vehicle_best_320.pt"
model = YOLO(pt_path)
model.export(
    format="ncnn",
    half=True,
    optimize=False
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.4.75 🚀 Python-3.12.13 torch-2.11.0+cu128 CPU (Intel Xeon CPU @ 2.00GHz)
# WARNING ⚠️ NCNN export does not support end2end models, disabling end2end branch.
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO11n summary (fused): 101 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from '/content/vehicle_best_320.pt' with input shape (1, 3, 320, 320) BCHW and output shape(s) (1, 9, 2100) (5.2 MB)
# requirements: Ultralytics requirement ['ncnn'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# ...

# %%
# !zip -r -q /content/vehicle_best_320_ncnn_model.zip /content/vehicle_best_320_ncnn_model
from google.colab import files
files.download('/content/vehicle_best_320_ncnn_model.zip')

# %%
# Export to NCNN
from ultralytics import YOLO

pt_path = "/content/vehicle_custom_best_320.pt"
model = YOLO(pt_path)
model.export(
    format="ncnn",
    half=True,
    optimize=False
)
# Out:
# Ultralytics 8.4.75 🚀 Python-3.12.13 torch-2.11.0+cu128 CPU (Intel Xeon CPU @ 2.00GHz)
# WARNING ⚠️ NCNN export does not support end2end models, disabling end2end branch.
# YOLO11n summary (fused): 101 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from '/content/vehicle_custom_best_320.pt' with input shape (1, 3, 320, 320) BCHW and output shape(s) (1, 9, 2100) (5.2 MB)
#
# NCNN: starting export with NCNN 1.0.20260526 and PNNX 20260526...
# NCNN: export success ✅ 3.2s, saved as '/content/vehicle_custom_best_320_ncnn_model' (5.1 MB)
#
# Export complete (3.4s)
# Results saved to /content/vehicle_custom_best_320_ncnn_model
# Predict:         yolo predict task=detect model=/content/vehicle_custom_best_320_ncnn_model imgsz=320 half
# Validate:        yolo val task=detect model=/content/vehicle_custom_best_320_ncnn_model imgsz=320 data=/content/dataset/data.yaml half
# Visualize:       https://netron.app
# '/content/vehicle_custom_best_320_ncnn_model'

# %%
# !zip -r -q /content/vehicle_custom_best_320_ncnn_model.zip /content/vehicle_custom_best_320_ncnn_model
from google.colab import files
files.download('/content/vehicle_custom_best_320_ncnn_model.zip')
